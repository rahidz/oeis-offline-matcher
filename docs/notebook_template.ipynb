# %% [markdown]
# # OEIS Offline Matcher – Notebook Scratchpad
#
# Replace the cell contents below with your own sequences. Requires that you built the SQLite DB already.

# %%
from oeis_matcher.api import analyze_sequence

# Example query: Fibonacci prefix
res = analyze_sequence("0,1,1,2,3,5", similarity=3, combos=0)
res["exact_matches"][:3]

# %%
# Transform search example
res_t = analyze_sequence("1,2,3,4,5", transform_limit=10, combos=0, similarity=0)
res_t["transform_matches"][:3]

# %%
# Combination search example (small demo)
res_c = analyze_sequence("3,5,7,9,11", combos=5, combo_coeffs=(1,2), combo_max_shift=1, combo_candidates=40)
res_c["combinations"]
